# %% [markdown]
# # Project 3: Poisonous mushrooms

# %% [markdown]
# In this project, you'll investigate properties of mushrooms. This classic dataset contains over 8000 observations, where each mushroom is described by a variety of features like color, odor, etc., and the target variable is an indicator for whether the mushroom is poisonous. Since all the observations are categorical, I've binarized the feature space. Look at the feature_names below to see all 126 binary names.
#
# You'll start by running PCA to reduce the dimensionality from 126 down to 2 so that you can easily visualize the data. In general, PCA is very useful for visualization (though sklearn.manifold.tsne is known to produce better visualizations). Recall that PCA is a linear transformation. The 1st projected dimension is the linear combination of all 126 original features that captures as much of the variance in the data as possible. The 2nd projected dimension is the linear combination of all 126 original features that captures as much of the remaining variance as possible. The idea of dense low dimensional representations is crucial to machine learning!
#
# Once you've projected the data to 2 dimensions, you'll experiment with clustering using KMeans and density estimation with Gaussian Mixture Models. Finally, you'll train a classifier by fitting a GMM for the positive class and a GMM for the negative class, and perform inference by comparing the probabilities output by each model.
#
# As always, you're welcome to work on the project in groups and discuss ideas on the course wall, but please prepare your own write-up and write your own code.

# %%
# %matplotlib inline

import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn import mixture
from sklearn.mixture import GMM
from matplotlib.colors import LogNorm
from matplotlib.patches import Circle

# %% [markdown]
# Load feature names.

# %%
feature_names = []
with open('../Data/mushroom.map') as fmap:
    for line in fmap:
        [index, name, junk] = line.split()
        feature_names.append(name)

print 'Loaded feature names:', len(feature_names)
# Out:
# Loaded feature names: 126

# %% [markdown]
# Load data. The data is sparse in the input file, but there aren't too many features, so we'll use a dense representation, which is supported by all sklearn objects.

# %%
X, Y = [], []

with open('../Data/mushroom.data') as fdata:
    for line in fdata:
        items = line.split()
        Y.append(int(items.pop(0)))
        x = np.zeros(len(feature_names))
        for item in items:
            feature = int(item.split(':')[0])
            x[feature] = 1
        X.append(x)

# Convert these lists to numpy arrays.
X = np.array(X)
Y = np.array(Y)

# Split into train and test data.
train_data, train_labels = X[:7000], Y[:7000]
test_data, test_labels = X[7000:], Y[7000:]

# Check that the shapes look right.
print train_data.shape, test_data.shape
# Out:
# (7000, 126) (1124, 126)

# %% [markdown]
# (1) Run Principal Components Analysis on the data. Show what fraction of the total variance in the training data is explained by the first k principal components, for k in [1, 50].

# %%
def P1():
### STUDENT START ###

    for i in range(1,51):
        pca = PCA(n_components=i)
        pca.fit(train_data)
        print "Fraction of the total variance in the training data explained by the {0} principal component(s): {1:.3g}".format(i, np.sum(pca.explained_variance_ratio_))

### STUDENT END ###

P1()
# Out:
# Fraction of the total variance in the training data explained by the 1 principal component(s): 0.164
# Fraction of the total variance in the training data explained by the 2 principal component(s): 0.297
# Fraction of the total variance in the training data explained by the 3 principal component(s): 0.399
# Fraction of the total variance in the training data explained by the 4 principal component(s): 0.47
# Fraction of the total variance in the training data explained by the 5 principal component(s): 0.508
# Fraction of the total variance in the training data explained by the 6 principal component(s): 0.545
# Fraction of the total variance in the training data explained by the 7 principal component(s): 0.576
# Fraction of the total variance in the training data explained by the 8 principal component(s): 0.604
# Fraction of the total variance in the training data explained by the 9 principal component(s): 0.63
# Fraction of the total variance in the training data explained by the 10 principal component(s): 0.652
# Fraction of the total variance in the training data explained by the 11 principal component(s): 0.673
# Fraction of the total variance in the training data explained by the 12 principal component(s): 0.691
# Fraction of the total variance in the training data explained by the 13 principal component(s): 0.709
# Fraction of the total variance in the training data explained by the 14 principal component(s): 0.726
# Fraction of the total variance in the training data explained by the 15 principal component(s): 0.741
# Fraction of the total variance in the training data explained by the 16 principal component(s): 0.756
# Fraction of the total variance in the training data explained by the 17 principal component(s): 0.77
# Fraction of the total variance in the training data explained by the 18 principal component(s): 0.784
# Fraction of the total variance in the training data explained by the 19 principal component(s): 0.797
# Fraction of the total variance in the training data explained by the 20 principal component(s): 0.809
# Fraction of the total variance in the training data explained by the 21 principal component(s): 0.82
# Fraction of the total variance in the training data explained by the 22 principal component(s): 0.83
# Fraction of the total variance in the training data explained by the 23 principal component(s): 0.841
# Fraction of the total variance in the training data explained by the 24 principal component(s): 0.851
# Fraction of the total variance in the training data explained by the 25 principal component(s): 0.86
# Fraction of the total variance in the training data explained by the 26 principal component(s): 0.868
# Fraction of the total variance in the training data explained by the 27 principal component(s): 0.876
# Fraction of the total variance in the training data explained by the 28 principal component(s): 0.884
# Fraction of the total variance in the training data explained by the 29 principal component(s): 0.891
# Fraction of the total variance in the training data explained by the 30 principal component(s): 0.898
# Fraction of the total variance in the training data explained by the 31 principal component(s): 0.905
# Fraction of the total variance in the training data explained by the 32 principal component(s): 0.911
# Fraction of the total variance in the training data explained by the 33 principal component(s): 0.917
# Fraction of the total variance in the training data explained by the 34 principal component(s): 0.922
# Fraction of the total variance in the training data explained by the 35 principal component(s): 0.927
# Fraction of the total variance in the training data explained by the 36 principal component(s): 0.932
# Fraction of the total variance in the training data explained by the 37 principal component(s): 0.937
# Fraction of the total variance in the training data explained by the 38 principal component(s): 0.942
# Fraction of the total variance in the training data explained by the 39 principal component(s): 0.947
# Fraction of the total variance in the training data explained by the 40 principal component(s): 0.951
# Fraction of the total variance in the training data explained by the 41 principal component(s): 0.955
# Fraction of the total variance in the training data explained by the 42 principal component(s): 0.959
# Fraction of the total variance in the training data explained by the 43 principal component(s): 0.963
# Fraction of the total variance in the training data explained by the 44 principal component(s): 0.966
# Fraction of the total variance in the training data explained by the 45 principal component(s): 0.97
# Fraction of the total variance in the training data explained by the 46 principal component(s): 0.973
# Fraction of the total variance in the training data explained by the 47 principal component(s): 0.975
# Fraction of the total variance in the training data explained by the 48 principal component(s): 0.978
# Fraction of the total variance in the training data explained by the 49 principal component(s): 0.98
# Fraction of the total variance in the training data explained by the 50 principal component(s): 0.982

# %% [markdown]
# (2) PCA can be very useful for visualizing data. Project the training data down to 2 dimensions and plot it. Show the positive (poisonous) cases in blue and the negative (non-poisonous) in red. Here's a reference for plotting: http://matplotlib.org/users/pyplot_tutorial.html

# %%
def P2():
### STUDENT START ###

    pca = PCA(n_components=2)
    pca.fit(train_data)
    df = pd.DataFrame(pca.transform(train_data), columns = ['pc_1', 'pc_2'])
    
    indice_poisonous = train_labels == 1
    indice_non_poisonous = train_labels == 0

    plt.plot(df['pc_1'][indice_poisonous], df['pc_2'][indice_poisonous], 'bo')
    plt.plot(df['pc_1'][indice_non_poisonous], df['pc_2'][indice_non_poisonous], 'ro')
    plt.xlabel('Principal Component 1')
    plt.ylabel('Principal Component 2')
    plt.show()

### STUDENT END ###

P2()

# %% [markdown]
# (3) Run KMeans with [1,16] clusters over the 2d projected data. Mark each centroid cluster and plot a circle that goes through the most distant point assigned to each cluster.

# %%
def P3():
### STUDENT START ###       

    pca = PCA(n_components=2)
    pca.fit(train_data)
    df = pd.DataFrame(pca.transform(train_data), columns = ['pc_1', 'pc_2'])
    
    # Initiailize figure
    fig1 = plt.figure(figsize=(8,8))
    
    # Count varible for keeping track of figures 
    count_figures = 1
        
    for i in range(1, 17):
        kmeans = KMeans(n_clusters=i)
        dists = pd.DataFrame(kmeans.fit_transform(df))
        
        centroids = kmeans.cluster_centers_
        labels = kmeans.labels_

        ax1 = fig1.add_subplot(4, 4, count_figures, aspect='equal')
        
        for label in set(labels):
            centroid = centroids[label]
            indice_current_label = labels == label
            points = np.array(df[indice_current_label])
            current_dists = list(dists[indice_current_label][label])
            
            # Get the most distant point from the centroid
            farthest_point = points[current_dists.index(max(current_dists))]

            ax1.plot(
                points.T[0], points.T[1], label='{} cluster'.format(i), linestyle='none', marker='o', mec='none',
            )            
            circle = plt.Circle(
                (centroid[0], centroid[1]), max(current_dists), linestyle='solid', linewidth=1, fill=False)
            ax1.add_patch(circle)
            ax1.plot(
                centroid[0], centroid[1], label='{} cluster'.format(i), linestyle='none', marker='o', mec='none',
            )
            ax1.plot(
                farthest_point[0], farthest_point[1], label='{} cluster'.format(i), linestyle='none', marker='o',
                mec='none',
            )
        
        # Increment the counter for figures
        count_figures = count_figures + 1
    
### STUDENT END ###

P3()

# %% [markdown]
# (4) Fit a Gaussian Mixture Model for the positive examples in your 2d projected data. Plot the estimated density contours as shown here: http://scikit-learn.org/stable/auto_examples/mixture/plot_gmm_pdf.html#example-mixture-plot-gmm-pdf-py. Vary the number of mixture components from 1-4 and the covariance matrix type ('spherical', 'diag', 'tied', 'full').

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
def P4():
### STUDENT START ###

    pca = PCA(n_components=2)
    pca.fit(train_data)
    train_data_transformed = pca.transform(train_data)
    X_train = train_data_transformed[train_labels == 1]

    # Initiailize figure
    fig1 = plt.figure(figsize=(10, 10))
    
    # Count varible for keeping track of figures
    count_figures = 1

    for i in range(0, 5):
        ax1 = fig1.add_subplot(5, 5, count_figures, aspect='0.3')
        ax1.axis('off')
        
        # If not 0, print out the current row number i
        if i != 0:
            ax1.text(0.5, 0.5, 'n='+str(i), fontsize=12)

        # Increment the counter for figures
        count_figures = count_figures + 1
        
        for covariance in ('spherical', 'diag', 'tied', 'full'):
            
            # Print out the header if i == 0
            if i == 0:
                ax1 = fig1.add_subplot(5, 5, count_figures, aspect='equal')
                ax1.text(0, 0, covariance, fontsize=12, horizontalalignment='left',
                         verticalalignment='bottom')
                ax1.axis('off')
                count_figures = count_figures + 1
                continue
            
            # If not header, make the aspect ratio equal
            ax1 = fig1.add_subplot(5, 5, count_figures, aspect='equal')
                
            # fit a Gaussian Mixture Model with two components
            clf = mixture.GaussianMixture(n_components=i, covariance_type=covariance)
            clf.fit(X_train)

            # display predicted scores by the model as a contour plot
            x = np.linspace(-3., 3.)
            y = np.linspace(-3., 3.)
            X, Y = np.meshgrid(x, y)
            XX = np.array([X.ravel(), Y.ravel()]).T
            Z = -clf.score_samples(XX)
            Z = Z.reshape(X.shape)

            CS = plt.contour(X, Y, Z, norm=LogNorm(vmin=1.0, vmax=1000.0),
                             levels=np.logspace(0, 3, 10))
            CB = plt.colorbar(CS, shrink=0.8, extend='both')
            plt.scatter(X_train[:, 0], X_train[:, 1], .8)
            
            # Increment the counter for figures
            count_figures = count_figures + 1
    
### STUDENT END ###

P4()

# %% [markdown]
# (5) Fit two 4-component full covariance GMMs, one for the positive examples and one for the negative examples in your 2d projected data. Predict the test examples by choosing the label for which the model gives a larger probability (use GMM.score). What is the accuracy?

# %%
def P5():
### STUDENT START ###

    pca = PCA(n_components=2)
    pca.fit(train_data)
    train_data_transformed = pca.transform(train_data)
    X_train_pos = train_data_transformed[train_labels == 1]
    X_train_neg = train_data_transformed[train_labels == 0]
    X_test = pca.transform(test_data)

    # fit a 4-component full covariance GMM for positive examples
    clf_pos = mixture.GaussianMixture(n_components=4, covariance_type='full')
    clf_pos.fit(X_train_pos)
    scores_pos = clf_pos.score_samples(X_test)

    # fit a 4-component full covariance GMM for negative examples
    clf_neg = mixture.GaussianMixture(n_components=4, covariance_type='full')
    clf_neg.fit(X_train_neg)
    scores_neg = clf_neg.score_samples(X_test)
    
    preds = []
    
    for i in range(0, len(scores_pos)):
        if scores_pos[i] > scores_neg[i]:
            preds.append(1)
        else:
            preds.append(0)

    print "Accuracy: {:.4}".format(np.mean(preds == test_labels))
    
    
### STUDENT END ###

P5()
# Out:
# Accuracy: 0.9368

# %% [markdown]
# (6) Ideally, we'd like a model that gives the best accuracy with the fewest parameters. Run a series of experiments to find the model that gives the best accuracy with no more than 50 parameters. For example, with 3 PCA components and 2-component diagonal covariance GMMs, you'd have:
#
# ( (3 mean vector + 3 covariance matrix) x 2 components ) x 2 classes = 24 parameters
#
# You should vary the number of PCA components, the number of GMM components, and the covariance type.

# %%
def P6():
### STUDENT START ###

    # If the total number of parameters are equal to or less than 50
    # return the number of parameters. If not, return False
    def check_params(n_pca, n_gmm, cov):
        num_params = n_pca * 2 * n_gmm * 2
        
        if num_params <= 50:
            return num_params
        else:
            return False

    # Given a set of parameters and train/test data, return the accuracy of the model
    def run_model(train_data, test_data, test_labels, n_pca, n_gmm, cov):
        pca = PCA(n_components=n_pca)
        pca.fit(train_data)
        X_train = pca.transform(train_data)
        X_train_pos = X_train[train_labels == 1]
        X_train_neg = X_train[train_labels == 0]
        X_test = pca.transform(test_data)

        # fit a 4-component full covariance GMM for positive examples
        clf_pos = mixture.GaussianMixture(n_components=n_gmm, covariance_type=cov)
        clf_pos.fit(X_train_pos)
        scores_pos = clf_pos.score_samples(X_test)

        # fit a 4-component full covariance GMM for negative examples
        clf_neg = mixture.GaussianMixture(n_components=n_gmm, covariance_type=cov)
        clf_neg.fit(X_train_neg)
        scores_neg = clf_neg.score_samples(X_test)
        
        preds = []

        for i in range(0, len(scores_pos)):
            if scores_pos[i] > scores_neg[i]:
                preds.append(1)
            else:
                preds.append(0)
        
        return np.mean(preds == test_labels)
    
    # Create an empty dataframe
    accuracies = pd.DataFrame([], columns=['accuracy', 'n_pca', 'n_gmm', 'covariance'])
       
    for i in range(1, 21):
        for j in range(1, 21):
            for covariance in ('spherical', 'diag', 'tied', 'full'):
                num_params = check_params(i, j, covariance)
                
                if not num_params:
                    continue

                accuracy = run_model(train_data, test_data, test_labels, i, j, covariance)

                accuracies = accuracies.append({
                    'accuracy': accuracy,
                    'n_pca': i,
                    'n_gmm': j,
                    'covariance': covariance
                }, ignore_index=True)
                
                print "Accuracy: {0:.4} - {1} parameters ({2} PCA Components, {3} GMM Components " \
                "and Covariance Type {4})".format(
                   accuracy,
                   num_params,
                   i,
                   j,
                   covariance
                )

    # Get the top 5 results
    results = accuracies.sort_values(by='accuracy', ascending=False)[:5]    

    print "\nBest 5 parameter combinations with highest accuracies:"
    
    for i in range(0, 5):
        print "Accuracy: {0:.4} - {1} parameters ({2} PCA Components, {3} GMM Components " \
        "and Covariance Type {4})".format(
            results.iloc[i, 0],
            check_params(results.iloc[i, 1], results.iloc[i, 2], results.iloc[i, 3]),
            results.iloc[i, 1],
            results.iloc[i, 2],
            results.iloc[i, 3],
        )
    
### STUDENT END ###

P6()
# Out:
# Accuracy: 0.8443 - 4 parameters (1 PCA Components, 1 GMM Components and Covariance Type spherical)
# Accuracy: 0.8443 - 4 parameters (1 PCA Components, 1 GMM Components and Covariance Type diag)
# Accuracy: 0.8443 - 4 parameters (1 PCA Components, 1 GMM Components and Covariance Type tied)
# Accuracy: 0.8443 - 4 parameters (1 PCA Components, 1 GMM Components and Covariance Type full)
# Accuracy: 0.8986 - 8 parameters (1 PCA Components, 2 GMM Components and Covariance Type spherical)
# Accuracy: 0.8986 - 8 parameters (1 PCA Components, 2 GMM Components and Covariance Type diag)
# Accuracy: 0.8835 - 8 parameters (1 PCA Components, 2 GMM Components and Covariance Type tied)
# Accuracy: 0.8986 - 8 parameters (1 PCA Components, 2 GMM Components and Covariance Type full)
# Accuracy: 0.9093 - 12 parameters (1 PCA Components, 3 GMM Components and Covariance Type spherical)
# Accuracy: 0.9093 - 12 parameters (1 PCA Components, 3 GMM Components and Covariance Type diag)
# Accuracy: 0.9155 - 12 parameters (1 PCA Components, 3 GMM Components and Covariance Type tied)
# Accuracy: 0.9084 - 12 parameters (1 PCA Components, 3 GMM Components and Covariance Type full)
# Accuracy: 0.9164 - 16 parameters (1 PCA Components, 4 GMM Components and Covariance Type spherical)
# Accuracy: 0.9137 - 16 parameters (1 PCA Components, 4 GMM Components and Covariance Type diag)
# Accuracy: 0.9164 - 16 parameters (1 PCA Components, 4 GMM Components and Covariance Type tied)
# Accuracy: 0.9137 - 16 parameters (1 PCA Components, 4 GMM Components and Covariance Type full)
# Accuracy: 0.9128 - 20 parameters (1 PCA Components, 5 GMM Components and Covariance Type spherical)
# Accuracy: 0.9128 - 20 parameters (1 PCA Components, 5 GMM Components and Covariance Type diag)
# Accuracy: 0.9128 - 20 parameters (1 PCA Components, 5 GMM Components and Covariance Type tied)
# Accuracy: 0.911 - 20 parameters (1 PCA Components, 5 GMM Components and Covariance Type full)
# Accuracy: 0.9119 - 24 parameters (1 PCA Components, 6 GMM Components and Covariance Type spherical)
# Accuracy: 0.9101 - 24 parameters (1 PCA Components, 6 GMM Components and Covariance Type diag)
# Accuracy: 0.9119 - 24 parameters (1 PCA Components, 6 GMM Components and Covariance Type tied)
# Accuracy: 0.9093 - 24 parameters (1 PCA Components, 6 GMM Components and Covariance Type full)
# Accuracy: 0.9093 - 28 parameters (1 PCA Components, 7 GMM Components and Covariance Type spherical)
# Accuracy: 0.9093 - 28 parameters (1 PCA Components, 7 GMM Components and Covariance Type diag)
# Accuracy: 0.9137 - 28 parameters (1 PCA Components, 7 GMM Components and Covariance Type tied)
# Accuracy: 0.9093 - 28 parameters (1 PCA Components, 7 GMM Components and Covariance Type full)
# Accuracy: 0.911 - 32 parameters (1 PCA Components, 8 GMM Components and Covariance Type spherical)
# Accuracy: 0.911 - 32 parameters (1 PCA Components, 8 GMM Components and Covariance Type diag)
# Accuracy: 0.9093 - 32 parameters (1 PCA Components, 8 GMM Components and Covariance Type tied)
# Accuracy: 0.9084 - 32 parameters (1 PCA Components, 8 GMM Components and Covariance Type full)
# Accuracy: 0.9137 - 36 parameters (1 PCA Components, 9 GMM Components and Covariance Type spherical)
# Accuracy: 0.9146 - 36 parameters (1 PCA Components, 9 GMM Components and Covariance Type diag)
# Accuracy: 0.9119 - 36 parameters (1 PCA Components, 9 GMM Components and Covariance Type tied)
# Accuracy: 0.9155 - 36 parameters (1 PCA Components, 9 GMM Components and Covariance Type full)
# Accuracy: 0.9146 - 40 parameters (1 PCA Components, 10 GMM Components and Covariance Type spherical)
# Accuracy: 0.9155 - 40 parameters (1 PCA Components, 10 GMM Components and Covariance Type diag)
# Accuracy: 0.911 - 40 parameters (1 PCA Components, 10 GMM Components and Covariance Type tied)
# Accuracy: 0.9155 - 40 parameters (1 PCA Components, 10 GMM Components and Covariance Type full)
# Accuracy: 0.9101 - 44 parameters (1 PCA Components, 11 GMM Components and Covariance Type spherical)
# Accuracy: 0.911 - 44 parameters (1 PCA Components, 11 GMM Components and Covariance Type diag)
# Accuracy: 0.9119 - 44 parameters (1 PCA Components, 11 GMM Components and Covariance Type tied)
# Accuracy: 0.9146 - 44 parameters (1 PCA Components, 11 GMM Components and Covariance Type full)
# Accuracy: 0.9155 - 48 parameters (1 PCA Components, 12 GMM Components and Covariance Type spherical)
# Accuracy: 0.9119 - 48 parameters (1 PCA Components, 12 GMM Components and Covariance Type diag)
# Accuracy: 0.9146 - 48 parameters (1 PCA Components, 12 GMM Components and Covariance Type tied)
# Accuracy: 0.9101 - 48 parameters (1 PCA Components, 12 GMM Components and Covariance Type full)
# Accuracy: 0.8603 - 8 parameters (2 PCA Components, 1 GMM Components and Covariance Type spherical)
# Accuracy: 0.8621 - 8 parameters (2 PCA Components, 1 GMM Components and Covariance Type diag)
# Accuracy: 0.8621 - 8 parameters (2 PCA Components, 1 GMM Components and Covariance Type tied)
# Accuracy: 0.8621 - 8 parameters (2 PCA Components, 1 GMM Components and Covariance Type full)
# Accuracy: 0.8763 - 16 parameters (2 PCA Components, 2 GMM Components and Covariance Type spherical)
# Accuracy: 0.8728 - 16 parameters (2 PCA Components, 2 GMM Components and Covariance Type diag)
# Accuracy: 0.9253 - 16 parameters (2 PCA Components, 2 GMM Components and Covariance Type tied)
# Accuracy: 0.9324 - 16 parameters (2 PCA Components, 2 GMM Components and Covariance Type full)
# Accuracy: 0.9457 - 24 parameters (2 PCA Components, 3 GMM Components and Covariance Type spherical)
# Accuracy: 0.9475 - 24 parameters (2 PCA Components, 3 GMM Components and Covariance Type diag)
# Accuracy: 0.9448 - 24 parameters (2 PCA Components, 3 GMM Components and Covariance Type tied)
# Accuracy: 0.9359 - 24 parameters (2 PCA Components, 3 GMM Components and Covariance Type full)
# Accuracy: 0.9457 - 32 parameters (2 PCA Components, 4 GMM Components and Covariance Type spherical)
# Accuracy: 0.9404 - 32 parameters (2 PCA Components, 4 GMM Components and Covariance Type diag)
# Accuracy: 0.9457 - 32 parameters (2 PCA Components, 4 GMM Components and Covariance Type tied)
# Accuracy: 0.9502 - 32 parameters (2 PCA Components, 4 GMM Components and Covariance Type full)
# Accuracy: 0.9395 - 40 parameters (2 PCA Components, 5 GMM Components and Covariance Type spherical)
# Accuracy: 0.9297 - 40 parameters (2 PCA Components, 5 GMM Components and Covariance Type diag)
# Accuracy: 0.9511 - 40 parameters (2 PCA Components, 5 GMM Components and Covariance Type tied)
# Accuracy: 0.9493 - 40 parameters (2 PCA Components, 5 GMM Components and Covariance Type full)
# Accuracy: 0.9404 - 48 parameters (2 PCA Components, 6 GMM Components and Covariance Type spherical)
# Accuracy: 0.9324 - 48 parameters (2 PCA Components, 6 GMM Components and Covariance Type diag)
# Accuracy: 0.9475 - 48 parameters (2 PCA Components, 6 GMM Components and Covariance Type tied)
# Accuracy: 0.9582 - 48 parameters (2 PCA Components, 6 GMM Components and Covariance Type full)
# Accuracy: 0.8719 - 12 parameters (3 PCA Components, 1 GMM Components and Covariance Type spherical)
# Accuracy: 0.8692 - 12 parameters (3 PCA Components, 1 GMM Components and Covariance Type diag)
# Accuracy: 0.8657 - 12 parameters (3 PCA Components, 1 GMM Components and Covariance Type tied)
# Accuracy: 0.8657 - 12 parameters (3 PCA Components, 1 GMM Components and Covariance Type full)
# Accuracy: 0.8683 - 24 parameters (3 PCA Components, 2 GMM Components and Covariance Type spherical)
# Accuracy: 0.8594 - 24 parameters (3 PCA Components, 2 GMM Components and Covariance Type diag)
# Accuracy: 0.855 - 24 parameters (3 PCA Components, 2 GMM Components and Covariance Type tied)
# Accuracy: 0.8185 - 24 parameters (3 PCA Components, 2 GMM Components and Covariance Type full)
# Accuracy: 0.9066 - 36 parameters (3 PCA Components, 3 GMM Components and Covariance Type spherical)
# Accuracy: 0.9137 - 36 parameters (3 PCA Components, 3 GMM Components and Covariance Type diag)
# Accuracy: 0.9235 - 36 parameters (3 PCA Components, 3 GMM Components and Covariance Type tied)
# Accuracy: 0.9093 - 36 parameters (3 PCA Components, 3 GMM Components and Covariance Type full)
# Accuracy: 0.9635 - 48 parameters (3 PCA Components, 4 GMM Components and Covariance Type spherical)
# Accuracy: 0.9537 - 48 parameters (3 PCA Components, 4 GMM Components and Covariance Type diag)
# Accuracy: 0.9511 - 48 parameters (3 PCA Components, 4 GMM Components and Covariance Type tied)
# Accuracy: 0.9528 - 48 parameters (3 PCA Components, 4 GMM Components and Covariance Type full)
# Accuracy: 0.863 - 16 parameters (4 PCA Components, 1 GMM Components and Covariance Type spherical)
# Accuracy: 0.8434 - 16 parameters (4 PCA Components, 1 GMM Components and Covariance Type diag)
# Accuracy: 0.8167 - 16 parameters (4 PCA Components, 1 GMM Components and Covariance Type tied)
# Accuracy: 0.8167 - 16 parameters (4 PCA Components, 1 GMM Components and Covariance Type full)
# Accuracy: 0.8532 - 32 parameters (4 PCA Components, 2 GMM Components and Covariance Type spherical)
# Accuracy: 0.8132 - 32 parameters (4 PCA Components, 2 GMM Components and Covariance Type diag)
# Accuracy: 0.8585 - 32 parameters (4 PCA Components, 2 GMM Components and Covariance Type tied)
# Accuracy: 0.879 - 32 parameters (4 PCA Components, 2 GMM Components and Covariance Type full)
# Accuracy: 0.9119 - 48 parameters (4 PCA Components, 3 GMM Components and Covariance Type spherical)
# Accuracy: 0.911 - 48 parameters (4 PCA Components, 3 GMM Components and Covariance Type diag)
# Accuracy: 0.9698 - 48 parameters (4 PCA Components, 3 GMM Components and Covariance Type tied)
# Accuracy: 0.8897 - 48 parameters (4 PCA Components, 3 GMM Components and Covariance Type full)
# Accuracy: 0.8719 - 20 parameters (5 PCA Components, 1 GMM Components and Covariance Type spherical)
# Accuracy: 0.8781 - 20 parameters (5 PCA Components, 1 GMM Components and Covariance Type diag)
# Accuracy: 0.9457 - 20 parameters (5 PCA Components, 1 GMM Components and Covariance Type tied)
# Accuracy: 0.9457 - 20 parameters (5 PCA Components, 1 GMM Components and Covariance Type full)
# Accuracy: 0.8737 - 40 parameters (5 PCA Components, 2 GMM Components and Covariance Type spherical)
# Accuracy: 0.887 - 40 parameters (5 PCA Components, 2 GMM Components and Covariance Type diag)
# Accuracy: 0.9689 - 40 parameters (5 PCA Components, 2 GMM Components and Covariance Type tied)
# Accuracy: 0.96 - 40 parameters (5 PCA Components, 2 GMM Components and Covariance Type full)
# Accuracy: 0.8781 - 24 parameters (6 PCA Components, 1 GMM Components and Covariance Type spherical)
# Accuracy: 0.8852 - 24 parameters (6 PCA Components, 1 GMM Components and Covariance Type diag)
# Accuracy: 0.9528 - 24 parameters (6 PCA Components, 1 GMM Components and Covariance Type tied)
# Accuracy: 0.9528 - 24 parameters (6 PCA Components, 1 GMM Components and Covariance Type full)
# Accuracy: 0.96 - 48 parameters (6 PCA Components, 2 GMM Components and Covariance Type spherical)
# Accuracy: 0.8799 - 48 parameters (6 PCA Components, 2 GMM Components and Covariance Type diag)
# Accuracy: 0.9573 - 48 parameters (6 PCA Components, 2 GMM Components and Covariance Type tied)
# Accuracy: 0.9671 - 48 parameters (6 PCA Components, 2 GMM Components and Covariance Type full)
# Accuracy: 0.8763 - 28 parameters (7 PCA Components, 1 GMM Components and Covariance Type spherical)
# Accuracy: 0.911 - 28 parameters (7 PCA Components, 1 GMM Components and Covariance Type diag)
# Accuracy: 0.9653 - 28 parameters (7 PCA Components, 1 GMM Components and Covariance Type tied)
# Accuracy: 0.9653 - 28 parameters (7 PCA Components, 1 GMM Components and Covariance Type full)
# Accuracy: 0.8746 - 32 parameters (8 PCA Components, 1 GMM Components and Covariance Type spherical)
# Accuracy: 0.9128 - 32 parameters (8 PCA Components, 1 GMM Components and Covariance Type diag)
# Accuracy: 0.9626 - 32 parameters (8 PCA Components, 1 GMM Components and Covariance Type tied)
# Accuracy: 0.9626 - 32 parameters (8 PCA Components, 1 GMM Components and Covariance Type full)
# Accuracy: 0.8754 - 36 parameters (9 PCA Components, 1 GMM Components and Covariance Type spherical)
# Accuracy: 0.903 - 36 parameters (9 PCA Components, 1 GMM Components and Covariance Type diag)
# Accuracy: 0.9644 - 36 parameters (9 PCA Components, 1 GMM Components and Covariance Type tied)
# Accuracy: 0.9644 - 36 parameters (9 PCA Components, 1 GMM Components and Covariance Type full)
# Accuracy: 0.8772 - 40 parameters (10 PCA Components, 1 GMM Components and Covariance Type spherical)
# Accuracy: 0.9119 - 40 parameters (10 PCA Components, 1 GMM Components and Covariance Type diag)
# Accuracy: 0.9573 - 40 parameters (10 PCA Components, 1 GMM Components and Covariance Type tied)
# Accuracy: 0.9573 - 40 parameters (10 PCA Components, 1 GMM Components and Covariance Type full)
# Accuracy: 0.8772 - 44 parameters (11 PCA Components, 1 GMM Components and Covariance Type spherical)
# Accuracy: 0.9128 - 44 parameters (11 PCA Components, 1 GMM Components and Covariance Type diag)
# Accuracy: 0.9653 - 44 parameters (11 PCA Components, 1 GMM Components and Covariance Type tied)
# Accuracy: 0.9653 - 44 parameters (11 PCA Components, 1 GMM Components and Covariance Type full)
# Accuracy: 0.8772 - 48 parameters (12 PCA Components, 1 GMM Components and Covariance Type spherical)
# Accuracy: 0.9137 - 48 parameters (12 PCA Components, 1 GMM Components and Covariance Type diag)
# Accuracy: 0.9626 - 48 parameters (12 PCA Components, 1 GMM Components and Covariance Type tied)
# Accuracy: 0.9626 - 48 parameters (12 PCA Components, 1 GMM Components and Covariance Type full)
#
# Best 5 parameter combinations with highest accuracies:
# Accuracy: 0.9698 - 48 parameters (4 PCA Components, 3 GMM Components and Covariance Type tied)
# Accuracy: 0.9689 - 40 parameters (5 PCA Components, 2 GMM Components and Covariance Type tied)
# Accuracy: 0.9671 - 48 parameters (6 PCA Components, 2 GMM Components and Covariance Type full)
# Accuracy: 0.9653 - 28 parameters (7 PCA Components, 1 GMM Components and Covariance Type full)
# Accuracy: 0.9653 - 44 parameters (11 PCA Components, 1 GMM Components and Covariance Type full)
